# %% [markdown]
# # Load Forecasting

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
import openml
from torch.utils.data import Dataset, DataLoader

# %%
df = openml.datasets.get_dataset(46340)
df, _, _, _ = df.get_data()
df.drop(df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#                    date      temp      wind  sun      Load  Instant     Posan  \
# 0  2017-01-01T00:00:00Z -1.940235  1.968498  0.0  15052349        2  0.000114
# 1  2017-01-01T00:30:00Z -1.969982  1.977643  0.0  17580789        3  0.000171
# 2  2017-01-01T01:00:00Z -1.999729  1.986789  0.0  19854004        4  0.000228
# 3  2017-01-01T01:30:00Z -2.043080  1.987839  0.0  18741368        5  0.000285
# 4  2017-01-01T02:00:00Z -2.086432  1.988890  0.0  17859804        6  0.000342
#
#    JourSemaine  JourFerie  offset  DayType  Weekend  temp_liss_fort  \
# 0            0          1      20       30        1       -0.750143
# 1            0          1      20       30        1       -0.784298
# 2            0          1      20       30        1       -0.818330
# 3            0          1      20       30        1       -0.852623
# 4            0          1      20       30        1       -0.887170
#
#    temp_liss_faible   tempMax   tempMin
# 0          3.375117  2.814086 -2.120351
# 1          3.359082  2.814086 -2.120351
# 2          3.343006  2.814086 -2.120351
# 3          3.326847  2.814086 -2.120351
# 4          3.310607  2.814086 -2.120351

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,5))
df['date']= pd.to_datetime(df['date'])
df.set_index("date", inplace=True)
df = df[df.index.minute==0]

df_plot = df[(df.index.year == 2021)&(df.index.month==11)&(df.index.day>23)]
plt.plot(df_plot.index, df_plot['Load'], '--', c='g', label='Load Consumption')

plt.grid()
plt.ylabel('MW values', fontsize=14)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=True, ncol=4, fontsize="18") 
plt.show()

# %%
df_train = df[df.index.year<2020]
df_val = df[df.index.year==2021]
df_test = df[df.index.year==2022]

X_train = df_train.drop('Load', axis=1)
X_val = df_val.drop('Load', axis=1)
X_test = df_test.drop('Load', axis=1)

max_X = X_train.max(axis=0)*1.1
min_X = X_train.min(axis=0)*0.9
X_train = (X_train - min_X)/(max_X - min_X)
X_val = (X_val - min_X)/(max_X - min_X)
X_test = (X_test - min_X)/(max_X - min_X)

y_train = df_train[['Load']]
y_val = df_val[['Load']]
y_test = df_test[['Load']]

max_y = (y_train.max(axis=0)*1.1).item()
min_y = (y_train.min(axis=0)*0.9).item()
print(f"Training period: ({X_train.shape} | {y_train.shape}), val period: ({X_val.shape} | {y_val.shape}), test period: (({X_test.shape} | {y_test.shape}))")
# Out:
# Training period: ((26280, 14) | (26280, 1)), val period: ((8760, 14) | (8760, 1)), test period: (((8760, 14) | (8760, 1)))

# %%
class LoadDataset(Dataset):
    def __init__(self, X,y, min_y, max_y):
        self.X = X
        self.y = y
        self.dates = pd.unique(X.index.date)
        self.min_y = min_y
        self.max_y = max_y

    def __getitem__(self, index):
        idx = str(self.dates[index])
        x = self.X.loc[idx].values
        y = ((self.y.loc[idx] - self.min_y)/(self.max_y - self.min_y)).values.squeeze()
        return np.expand_dims(x, -1),y
    
    def denormalize(self, y):
        df = pd.DataFrame(index=self.X.index)
        df['Pred'] = y*(self.max_y - self.min_y) + self.min_y
        return df
    
    def __len__(self):
        return self.dates.shape[0]
    
train_set = LoadDataset(X_train, y_train, min_y, max_y)
val_set = LoadDataset(X_val, y_val, min_y, max_y)
test_set = LoadDataset(X_test, y_test, min_y, max_y)

train_loader = DataLoader(train_set, batch_size=64, shuffle=False)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False)
test_loader = DataLoader(test_set, batch_size=1, shuffle=False)

# %%
class LoadModel(nn.Module):
    def __init__(self, args, ts_shape):
        super().__init__()
        self.args = args
        self.input_shape = ts_shape

        # 2-dimensional DAG
        self.cell_2d = args['2D Dag']
        self.cell_2d.set(self.input_shape)

        # Compute after flatten
        self.flat_shape = (self.cell_2d.output_shape[0],np.prod(self.cell_2d.output_shape[1:]))

        # 1-dimensional DAG
        self.cell_1d = args['1D Dag']
        self.cell_1d.set(self.flat_shape)

        # Output layer
        self.output = args["Out"]
        args['Out'].set(self.cell_1d.output_shape)

    def forward(self, X):
        out_2d = self.cell_2d(X)
        flat = nn.Flatten(start_dim=2)(out_2d)
        out_1d = self.cell_1d(flat)
        out = self.output(out_1d)
        return out.squeeze(-1)
    
    def set_prediction_to_save(self, name, df):
        self.prediction = {name: df}
    
    def save(self, path):
        if not os.path.exists(path):
            os.makedirs(path)
        full_path = os.path.join(path, "best_model.pth")
        torch.save(self.state_dict(), full_path)
        if hasattr(self, "prediction"):
            for k in self.prediction.keys():
                self.prediction[k].to_csv(os.path.join(path, f"best_model_{k}_outputs.csv"))

# %%
from dragon.search_space.bricks_variables import mlp_var, dropout, identity_var, mlp_const_var, conv_1d, conv_2d, pooling_1d, pooling_2d, attention_1d, attention_2d, norm_1d, norm_2d
from dragon.search_space.bricks_variables import operations_var, dag_var, node_var
from dragon.search_space.base_variables import ArrayVar
from dragon.search_operators.base_neighborhoods import ArrayInterval
candidate_operations_2d = operations_var("2D Candidate operations", size=5, 
                                            candidates=[identity_var("Unitary"), attention_2d("Attention"), mlp_var("MLP"), conv_2d("Convolution", 24), 
                                                        pooling_2d('Pooling'), norm_2d("Norm"), dropout('Dropout')])

dag_2d = dag_var("2D Dag", candidate_operations_2d)

candidate_operations_1d = operations_var("2D Candidate operations", size=5, 
                                            candidates=[identity_var("Unitary"), attention_1d("Attention"), mlp_var("MLP"), conv_1d("Convolution", 24), 
                                                        pooling_1d('Pooling'), norm_1d("Norm"), dropout('Dropout')])
dag_1d = dag_var("1D Dag", candidate_operations_1d)
out = node_var("Out", operation=mlp_const_var('Operation', 1), activation_function=nn.Identity())

search_space = ArrayVar(dag_2d, dag_1d, out, label="Search Space", neighbor=ArrayInterval())
labels = [e.label for e in search_space]

# %%
def MSE(actual, pred):
    return np.mean((actual - pred) ** 2)


def MAPE(actual, pred):
    return np.mean(np.abs((actual - pred) / actual))


def RMSE(actual, pred):
    return np.sqrt(MSE(actual, pred))

def train_model(model, data_loader, verbose=False):
    loss_fn = nn.MSELoss()
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.01)
    model.train()
    for ep in range(20):
        ep_loss = 0
        for X,y in data_loader:
            optimizer.zero_grad()
            X, y = X.float(), y.float()
            pred = model(X)
            loss = loss_fn(pred,y)
            loss.backward()
            optimizer.step()
            ep_loss += loss
        if verbose:
            print(f"Train | Epoch: {ep}, loss = {ep_loss / len(data_loader)}")
    return model

def test_model(model, data_loader):
    loss_fn = nn.MSELoss()
    model.eval()
    test_loss = 0
    preds = []
    trues = []
    with torch.no_grad():
      for X, y in data_loader:
          X, y = X.float(), y.float()
          pred = model(X)
          loss = loss_fn(pred, y).item()
          test_loss += loss
          preds.append(pred.detach().numpy())
          trues.append(y.detach().numpy())
    loss = test_loss / len(data_loader)
    return loss, preds, trues

def loss_function(args, idx, verbose=False):
    args = dict(zip(labels, args))
    model = LoadModel(args, train_set.__getitem__(0)[0].shape)
    model = train_model(model, train_loader, verbose=verbose)
    loss, preds, trues = test_model(model, val_loader)
    preds = np.concatenate((np.asarray(preds[:-1]).reshape(-1,1), np.asarray(preds[-1]).reshape(-1,1)))
    trues = np.concatenate((np.asarray(trues[:-1]).reshape(-1,1), np.asarray(trues[-1]).reshape(-1,1)))
    preds = val_set.denormalize(preds)
    trues = val_set.denormalize(trues)
    mape = MAPE(trues, preds)
    rmse = RMSE(trues, preds)
    print(f"Idx: {idx}, on validation set: MAPE = {mape}, RMSE = {rmse}")
    return loss, model

args = search_space.random()
loss, model = loss_function(args, 0, verbose=True)
print(f'For a given argument, loss = {loss}')
# Out:
# Train | Epoch: 0, loss = 1.419350504875183
# Train | Epoch: 1, loss = 0.06321503967046738
# Train | Epoch: 2, loss = 0.04271344840526581
# Train | Epoch: 3, loss = 0.03690961375832558
# Train | Epoch: 4, loss = 0.03338288888335228
# Train | Epoch: 5, loss = 0.02776082418859005
# Train | Epoch: 6, loss = 0.030982736498117447
# Train | Epoch: 7, loss = 0.027922000735998154
# Train | Epoch: 8, loss = 0.020977305248379707
# Train | Epoch: 9, loss = 0.02019847370684147
# Train | Epoch: 10, loss = 0.01796489767730236
# Train | Epoch: 11, loss = 0.015478778630495071
# Train | Epoch: 12, loss = 0.013073945418000221
# Train | Epoch: 13, loss = 0.011364471167325974
# Train | Epoch: 14, loss = 0.010795779526233673
# Train | Epoch: 15, loss = 0.01022932305932045
# Train | Epoch: 16, loss = 0.009598475880920887
# Train | Epoch: 17, loss = 0.007999884895980358
# Train | Epoch: 18, loss = 0.010056881234049797
# Train | Epoch: 19, loss = 0.008712561801075935
# Idx: 0, on validation set: MAPE = 0.313894122838974, RMSE = 3017976.75
# For a given argument, loss = 0.008385379953930775

# %%
from dragon.search_algorithm.agentic import AgenticSearchAlgorithm, LLMPolicy, EnhancedLLMPolicy, AdaptiveLLMPolicy


search_algorithm = AgenticSearchAlgorithm(search_space, save_dir="save/test_load_agentic", T=20, N=5, K=5, E=0.01, evaluation=loss_function, 
                                          policy=AdaptiveLLMPolicy(api_key=api_key))
search_algorithm.run()
# Out:
# 2026-01-29 10:36:03,195 | WARNING | Use multiple processes if you want to use the distributed version.
# 2026-01-29 10:36:03,212 | INFO | The whole population has been created (size = 5), 5 have been randomy initialized.
# Idx: 0, on validation set: MAPE = 0.7268026471138, RMSE = 6793778.5
# 2026-01-29 10:36:46,810 | INFO | Best found! 0.043093521147966385 < inf
# Idx: 1, on validation set: MAPE = 0.8571352362632751, RMSE = 6594399.0
# 2026-01-29 10:37:25,298 | INFO | Best found! 0.03965586253131429 < 0.043093521147966385
# Idx: 2, on validation set: MAPE = 0.8092383742332458, RMSE = 6610789.0
# Idx: 3, on validation set: MAPE = 0.47372210025787354, RMSE = 10797751.0
# Idx: 4, on validation set: MAPE = 0.2820306718349457, RMSE = 3666001.25
# 2026-01-29 10:46:07,821 | INFO | Best found! 0.012395918020047247 < 0.03965586253131429
# 2026-01-29 10:46:07,867 | INFO | All models have been at least evaluated once, t = 5 < 20.
# 2026-01-29 10:46:07,869 | INFO | After initialisation, it remains 15 iterations.
# 🌡️  Temperature adjusted to 0.7 (progress: 25.0%)
# 2026-01-29 10:46:08,826 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: We are in the early stage of the search process (25% progress), but the best individual has a relatively low loss (0.012396) and has only been trained once. Training the best individual again could further improve its performance and provide a better foundation for future mutations or comparisons. The confidence level is set to 0.85 because there is a clear strategic choice to exploit the current best individual, but there is still some uncertainty in whether this will lead to overfitting or if exploration should be prioritized at this stage.
# Idx: 4, on validation set: MAPE = 0.4255683124065399, RMSE = 3122542.25
# 2026-01-29 10:49:17,415 | INFO | Best found! 0.008557591897745928 < 0.012395918020047247
# 🌡️  Temperature adjusted to 0.4 (progress: 30.0%)
# 2026-01-29 10:49:18,503 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: We are currently at 30% progress, which is considered the early to mid-stage of the search process. The best individual has been trained only twice, and its loss is significantly better than the mean loss of the population. Training the best individual again could lead to further improvement in its loss. Given the current stage and the potential for improvement, I am moderately to highly confident in this decision. The population's variance is moderate, suggesting a balance between exploration and exploitation is appropriate, but since we've just reached the 30% mark, focusing on the best individual for now seems like a reasonable strategy.
# Idx: 4, on validation set: MAPE = 1.1802005767822266, RMSE = 11456185.0
# 🌡️  Temperature adjusted to 0.4 (progress: 35.0%)
# 2026-01-29 10:52:27,303 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: The current progress is 35%, which is in the mid-stage of the search process. The best individual has a relatively low loss of 0.039656 and has only been trained once. Training the best individual again can help to further improve its performance and potentially reduce the loss. The population statistics show a moderate variance in loss, indicating that there is still room for improvement. Given the current state of the search, continuing to train the best individual is a reasonable choice, and the confidence level reflects the expectation that this action will lead to further improvement.
# Idx: 1, on validation set: MAPE = 0.8570268750190735, RMSE = 6594373.0
# 🌡️  Temperature adjusted to 0.4 (progress: 40.0%)
# 2026-01-29 10:53:06,927 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: DROP on worst
#    Reasoning: The current best loss is stagnating and even worsening, indicating that recent actions may not be effective. The population size is stable, but the variance in loss is moderate (std_loss = 0.022996), suggesting that the population is somewhat diverse. Given that we are at the mid-stage of the search process (40% progress), it's essential to balance exploitation and exploration. However, since the best individual has been trained multiple times without significant improvement, it's reasonable to consider exploring other options. Dropping the worst individual and replacing it with a random one can introduce new genetic material into the population, potentially leading to better solutions. The confidence level of 0.65 reflects the uncertainty in this decision, as dropping the worst individual may not necessarily lead to improvement, but it's a reasonable exploratory step given the current stagnation.
# Idx: 4, on validation set: MAPE = 0.8729461431503296, RMSE = 6763066.5
# 🌡️  Temperature adjusted to 0.4 (progress: 45.0%)
# 2026-01-29 10:53:44,406 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: DROP on worst
#    Reasoning: The population has very low variance, indicating a need to increase diversity. The best loss is also worsening, suggesting recent actions may not be effective. Given the current progress (45%) and the fact that the best individual has only been trained twice, it's essential to balance exploitation and exploration. Dropping the worst individual and replacing it with a random one can help introduce new genetic material and potentially lead to better solutions. The confidence level of 0.65 reflects the uncertainty in this decision, as there's no clear indication that dropping the worst individual will immediately improve the search process, but it's a necessary step to avoid stagnation and promote exploration.
# Idx: 5, on validation set: MAPE = 0.32539060711860657, RMSE = 2936442.25
# 2026-01-29 11:51:27,900 | INFO | Best found! 0.007703129279737671 < 0.008557591897745928
# 🌡️  Temperature adjusted to 0.4 (progress: 50.0%)
# 2026-01-29 11:51:29,562 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: DROP on worst
#    Reasoning: The current best loss is worsening, indicating that recent actions may not be effective. Given that we are at the mid-stage of the search process (50% progress), it's essential to balance exploitation and exploration. However, since the best individual's loss is not improving, and the population's variance is moderate (std_loss = 0.014287), dropping the worst individual could introduce new genetic material and potentially lead to better solutions. The confidence level of 0.65 reflects the uncertainty in this decision, as there's no clear indication that dropping the worst will immediately improve the search. This choice is based on the need to maintain diversity in the population and avoid overfitting to the current set of solutions.
# Idx: 6, on validation set: MAPE = 0.831199049949646, RMSE = 6629519.5
# 🌡️  Temperature adjusted to 0.4 (progress: 55.0%)
# 2026-01-29 11:52:09,638 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: The current progress is at 55%, which indicates we are in the mid-stage of the search process. The best individual has a low loss of 0.007703 and has only been trained once. Given the current stage and the potential for further improvement, training the best individual is a reasonable choice to balance exploitation and exploration. The confidence level is set to 0.85, reflecting a high degree of certainty in this decision, as the best individual has shown promising results and has not been over-trained.
# Idx: 5, on validation set: MAPE = 0.7012141942977905, RMSE = 6868010.0
# 🌡️  Temperature adjusted to 0.4 (progress: 60.0%)
# 2026-01-29 12:24:58,867 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: MUTATE on worst
#    Reasoning: The population has very low variance in loss, indicating a lack of diversity. Given that we are in the mid-stage of the search process (60% progress), balancing exploitation and exploration is key. Since the best individual has already been trained twice and shows a good loss, focusing on increasing diversity is crucial. Mutating the worst individual provides a chance to explore new configurations while potentially replacing a poorly performing individual. The chosen confidence level reflects a moderate degree of uncertainty, as mutating the worst individual could lead to either improvement or deterioration, but it's a necessary step to avoid convergence to a suboptimal solution.
# Idx: 7, on validation set: MAPE = 1.8603665828704834, RMSE = 10795479.0
# 🌡️  Temperature adjusted to 0.4 (progress: 65.0%)
# 2026-01-29 12:25:49,760 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: We are currently at 65% progress, which indicates we are in the mid-stage of the search process. The best loss trend is improving (-34.55% over the last 5 steps), suggesting that our current strategy is effective. The best individual has been trained only twice, which is relatively low compared to the maximum number of trainings. Given this information, it's reasonable to continue training the best individual to further exploit its potential and improve the overall performance. The confidence level of 0.85 reflects the fact that we are continuing a successful strategy with a clear direction, but still acknowledges some uncertainty due to the inherent randomness in the search process.
# Idx: 5, on validation set: MAPE = 0.8612952828407288, RMSE = 6594289.5
# 🌡️  Temperature adjusted to 0.1 (progress: 70.0%)
# 2026-01-29 12:57:26,271 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: The current progress is at 70%, which indicates we are in the late stage of the search process. The best individual has a relatively low loss of 0.030539 and has been trained only 3 times, suggesting there is still room for improvement through further training. The best loss trend is also improving, which supports the decision to continue training the best individual. Given the stage of the search and the performance of the best individual, I have high confidence in this decision.
# Idx: 5, on validation set: MAPE = 0.8612907528877258, RMSE = 6594289.5
# 🌡️  Temperature adjusted to 0.1 (progress: 75.0%)
# 2026-01-29 13:29:28,586 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: DROP on worst
#    Reasoning: The current best loss is worsening, indicating that recent actions may not be effective. The population size is stable, and the most common recent action is TRAIN. However, the TRAIN operation has a low success rate of 17%. Given that we are in the late stage of the search process (> 70% progress), it's essential to focus on exploitation, but also consider exploration to avoid overfitting. Dropping the worst individual and replacing it with a random one can help introduce new genetic material and potentially improve the population's diversity. The confidence level of 0.65 reflects the uncertainty in this decision, as there is no clear indication that dropping the worst individual will immediately improve the best loss.
# Idx: 8, on validation set: MAPE = 0.7911161184310913, RMSE = 6254237.0
# 🌡️  Temperature adjusted to 0.1 (progress: 80.0%)
# 2026-01-29 13:30:51,327 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.65):
#    Action: MUTATE on worst
#    Reasoning: The current population has very low variance, and the best loss is worsening, indicating that recent actions may not be effective. Given that we are in the late stage of the search process (> 70% progress), but the population is not diverse, I've decided to mutate the worst individual to increase diversity. The confidence level is moderate (0.65) because this is an exploratory decision, and there's uncertainty about the outcome. However, the potential benefits of increasing population diversity outweigh the risks, and this decision aligns with the strategy hints provided.
# Idx: 9, on validation set: MAPE = 0.11820685863494873, RMSE = 1090731.25
# 2026-01-29 13:33:30,104 | INFO | Best found! 0.001046516534794743 < 0.007703129279737671
# 🌡️  Temperature adjusted to 0.1 (progress: 85.0%)
# 2026-01-29 13:33:31,544 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.85):
#    Action: TRAIN on best
#    Reasoning: Given that we are in the late stage (85% progress) of the search process, the strategy should focus on exploitation to refine the best individual found so far. The best individual has a loss of 0.001047 and has only been trained once (N=1), indicating potential for further improvement with additional training. The recent trend shows that the best loss is stagnating or worsening, suggesting that the current exploration actions may not be effective. Therefore, training the best individual is the most logical choice to try and improve its performance. The confidence level of 0.85 reflects a high degree of certainty in this decision, given the late stage of the search and the potential for the best individual to improve with more training.
# Idx: 9, on validation set: MAPE = 0.08424100279808044, RMSE = 806683.9375
# 2026-01-29 13:38:42,300 | INFO | Best found! 0.0005668546315670634 < 0.001046516534794743
# 🌡️  Temperature adjusted to 0.1 (progress: 90.0%)
# 2026-01-29 13:38:43,599 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.92):
#    Action: TRAIN on best
#    Reasoning: We are in the late stage of the search process (90% progress), and the best loss trend is improving (-95.97% over the last 5 steps). The recent action distribution shows that TRAIN has been the most common action, and the population size is stable. Given that the best individual has only been trained twice (N=2), there is still room for improvement through further training. The high confidence level (0.92) reflects the clear strategic choice to continue training the best individual, as the evidence suggests that this approach has been successful so far and the individual has not been overtrained.
# Idx: 9, on validation set: MAPE = 0.11441750079393387, RMSE = 922397.4375
# 🌡️  Temperature adjusted to 0.1 (progress: 95.0%)
# 2026-01-29 13:41:21,296 | INFO | HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# 🤖 LLM Decision (confidence: 0.92):
#    Action: TRAIN on best
#    Reasoning: We are in the late stage of the search process (95% progress), and the best individual has shown significant improvement in the recent steps. The best loss trend is also improving (-97.36% over the last 5 steps), indicating that the current strategy is effective. Given the high progress and the improving trend, the focus should be on exploitation to further refine the best individual. Training the best individual again is likely to yield further improvements, as it has done in the past steps (e.g., Step 17 and Step 18). The confidence level of 0.92 reflects the strong evidence supporting this decision, including the recent successful training steps and the overall progress of the search.
# Idx: 9, on validation set: MAPE = 0.07409421354532242, RMSE = 832062.125
# 2026-01-29 13:44:04,377 | INFO | Search algorithm is done. Min Loss = 0.0005668546315670634

# %%
from dragon.search_algorithm.ssea import SteadyStateEA

search_algorithm = SteadyStateEA(search_space, n_iterations=20, population_size=5, selection_size=3, evaluation = loss_function, save_dir="save/test_load")
min_loss = search_algorithm.run()

# %%
from dragon.utils.plot_functions import load_archi


best_model = load_archi("save/test_load_agentic/best_model/x.pkl")
print(best_model)
# Out:
# [ModuleList(
#   (0):
#   (input shape) (24, 14, 1) -- (combiner) add -- (op) Identity() -- (activation) Identity() -- (output shape) (24, 14, 1)
#   (1):
#   (input shape) (24, 14, 1) -- (combiner) mul -- (op) SpatialAttention() -- (activation) GELU(approximate='none') -- (output shape) (24, 14, 26)
#   (2):
#   (input shape) (24, 14, 26) -- (combiner) add -- (op) AVGPooling2D(
#     (pooling): AvgPool2d(kernel_size=(4, 4), stride=2, padding=0)
#   ) -- (activation) Tanh() -- (output shape) (24, 6, 12)
# ), ModuleList(
#   (0):
#   (input shape) (24, 72) -- (combiner) add -- (op) Identity() -- (activation) Identity() -- (output shape) (24, 72)
#   (1):
#   (input shape) (24, 72) -- (combiner) add -- (op) Attention1D(
#     (W_query): Linear(in_features=1, out_features=2, bias=True)
#     (W_key): Linear(in_features=1, out_features=2, bias=True)
#     (W): Linear(in_features=1, out_features=362, bias=True)
#   ) -- (activation) SiLU() -- (output shape) (24, 362)
#   (2):
#   (input shape) (24, 434) -- (combiner) concat -- (op) Dropout(
#     (dropout): Dropout(p=0.9027109914739408, inplace=False)
#   ) -- (activation) ReLU() -- (output shape) (24, 434)
#   (3):
#   (input shape) (24, 434) -- (combiner) add -- (op) AVGPooling1D(
#     (pooling): AvgPool1d(kernel_size=(10,), stride=(10,), padding=(0,))
#   ) -- (activation) Identity() -- (output shape) (24, 43)
# ),
# (input shape) (24, 43) -- (combiner) add -- (op) MLP(
#   (linear): Linear(in_features=36, out_features=1, bias=True)
# ) -- (activation) Identity() -- (output shape) (24, 1)]
